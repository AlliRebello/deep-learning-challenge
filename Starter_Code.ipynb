# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
display(application_df.head())
display(application_df.tail())
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 34294   Association       1          0                      N      5000
# 34295   Association       1          0                      N      5000
# 34296   Association       1          0                      N      5000
# 34297   Association       1          0                      N      5000
# 34298  Co-operative       1      1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_counts = application_df['APPLICATION_TYPE'].value_counts()
app_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_counts[app_type_counts<500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_value_counts = application_df['CLASSIFICATION'].value_counts()
class_value_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_type = class_value_counts.loc[class_value_counts > 1]
class_type
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_value_counts [class_value_counts <1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)
display(dummies_df.head())
display(dummies_df.tail())
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 34294       1      5000              0                   False
# 34295       1      5000              0                   False
# 34296       1      5000              0                   False
# 34297       1      5000              1                   False
# 34298       1  36500179              0                   False
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 34294                 False                 False                False
# 34295                 False                 False                False
# 34296                 False                 False                 True
# 34297                 False                 False                False
# 34298                 False                 False                 True
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 34294                 True                False                False  ...
# 34295                 True                False                False  ...
# 34296                False                False                False  ...
# 34297                False                 True                False  ...
# 34298                False                False                False  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 34294              False                   False                     False
# 34295              False                   False                     False
# 34296              False                   False                     False
# 34297              False                   False                     False
# 34298              False                   False                     False
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 34294               False             False                   False
# 34295               False             False                   False
# 34296               False             False                   False
# 34297               False             False                   False
# 34298               False              True                   False
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 34294            False              False                      True
# 34295            False              False                      True
# 34296            False              False                      True
# 34297            False              False                      True
# 34298            False              False                      True
#
#        SPECIAL_CONSIDERATIONS_Y
# 34294                     False
# 34295                     False
# 34296                     False
# 34297                     False
# 34298                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df['IS_SUCCESSFUL'].values
X = dummies_df.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
# Used 'stratify=y' to evenly distribute the trget variable (1's and 0's) amongst the traning and test data set. this gives us a more reflective dataset.
# Used 'test_size=.2' to give my training data set 80% ofthe data to work with.
# This will give my train set more data to train with to make it better at predicting.
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1,stratify=y,test_size=.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Will be using all the input features (43).
units_1 = 80
units_2 = 30
input_features = len(X_train_scaled[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=units_1, input_dim = input_features, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=units_2, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 4s 2ms/step - loss: 0.5722 - accuracy: 0.7190
# Epoch 2/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5565 - accuracy: 0.7277
# Epoch 3/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7300
# Epoch 4/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7293
# Epoch 5/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7295
# Epoch 6/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5498 - accuracy: 0.7301
# Epoch 7/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7294
# Epoch 8/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7293
# Epoch 9/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7316
# Epoch 10/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7312
# Epoch 11/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7312
# Epoch 12/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7318
# Epoch 13/100
# 858/858 [==============================] - 5s 6ms/step - loss: 0.5461 - accuracy: 0.7328
# Epoch 14/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5452 - accuracy: 0.7329
# Epoch 15/100
# 858/858 [==============================] - 8s 9ms/step - loss: 0.5451 - accuracy: 0.7337
# Epoch 16/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5449 - accuracy: 0.7329
# Epoch 17/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7331
# Epoch 18/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7323
# Epoch 19/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7344
# Epoch 20/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7339
# Epoch 21/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7347
# Epoch 22/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5435 - accuracy: 0.7336
# Epoch 23/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7342
# Epoch 24/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7345
# Epoch 25/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7340
# Epoch 26/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7333
# Epoch 27/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7352
# Epoch 28/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7356
# Epoch 29/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5424 - accuracy: 0.7348
# Epoch 30/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7357
# Epoch 31/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7358
# Epoch 32/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7347
# Epoch 33/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7352
# Epoch 34/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7353
# Epoch 35/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7351
# Epoch 36/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7352
# Epoch 37/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7356
# Epoch 38/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7354
# Epoch 39/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7353
# Epoch 40/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7353
# Epoch 41/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7353
# Epoch 42/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5405 - accuracy: 0.7357
# Epoch 43/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7356
# Epoch 44/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7354
# Epoch 45/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7353
# Epoch 46/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7356
# Epoch 47/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7360
# Epoch 48/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7351
# Epoch 49/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5401 - accuracy: 0.7364
# Epoch 50/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7364
# Epoch 51/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7361
# Epoch 52/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5397 - accuracy: 0.7361
# Epoch 53/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5391 - accuracy: 0.7373
# Epoch 54/100
# 858/858 [==============================] - 5s 5ms/step - loss: 0.5395 - accuracy: 0.7363
# Epoch 55/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7356
# Epoch 56/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7369
# Epoch 57/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7362
# Epoch 58/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7359
# Epoch 59/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7364
# Epoch 60/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5392 - accuracy: 0.7358
# Epoch 61/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7367
# Epoch 62/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7366
# Epoch 63/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7360
# Epoch 64/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7365
# Epoch 65/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7367
# Epoch 66/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5387 - accuracy: 0.7373
# Epoch 67/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5387 - accuracy: 0.7370
# Epoch 68/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7373
# Epoch 69/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7361
# Epoch 70/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7366
# Epoch 71/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7371
# Epoch 72/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7369
# Epoch 73/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5379 - accuracy: 0.7377
# Epoch 74/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7370
# Epoch 75/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7365
# Epoch 76/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7377
# Epoch 77/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7372
# Epoch 78/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7366
# Epoch 79/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5378 - accuracy: 0.7372
# Epoch 80/100
# 858/858 [==============================] - 6s 7ms/step - loss: 0.5378 - accuracy: 0.7372
# Epoch 81/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5378 - accuracy: 0.7361
# Epoch 82/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7370
# Epoch 83/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5378 - accuracy: 0.7375
# Epoch 84/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5375 - accuracy: 0.7369
# Epoch 85/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7377
# Epoch 86/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7362
# Epoch 87/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7371
# Epoch 88/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7369
# Epoch 89/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7371
# Epoch 90/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7369
# Epoch 91/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5373 - accuracy: 0.7371
# Epoch 92/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7374
# Epoch 93/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7381
# Epoch 94/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7375
# Epoch 95/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7367
# Epoch 96/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7372
# Epoch 97/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5368 - accuracy: 0.7373
# Epoch 98/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7377
# Epoch 99/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7369
# Epoch 100/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7378

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5541 - accuracy: 0.7389 - 456ms/epoch - 2ms/step
# Loss: 0.5541394948959351, Accuracy: 0.7389212846755981

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
